# %% [markdown]
# ![enter image description here](https://img.shields.io/badge/Author-Nestor_Batista_Díaz-yellow)

# %% [markdown]
# # Gestión de ficheros en Google colab

# %% [markdown]
# ## Sistema de archivos local de Google Colab
#
# Se ha subido el archivo "loremIpsum.txt"
#
# ![imagen_2023-10-21_112403359.png](data:image/png;base64,...)

# %% [markdown]
# ## Subir ficheros con Python desde el sistema local a los archivos de la sesión del notebook actual
#
# ### Ejer 01: Crear en el PC un fichero con un contenido de Loren Ipsum y subirlo

# %%
# !lsb_release -d
# Out:
# Description:	Ubuntu 22.04.2 LTS

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-b46c5370-910a-4ca8-a401-dceca973923c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b46c5370-910a-4ca8-a401-dceca973923c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Descargar archivos en el sistema de archivos local
#
# ### Ejer 02: Descargar el fichero subido en el apartado anterior

# %%
from google.colab import files

files.download('loremIpsum (1).txt')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Google Drive

# %% [markdown]
# ### Activar (Montar) Google Drive de forma local

# %%
# Muestra las unidades montadas
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   28G   81G  26% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.8G     0  5.8G   0% /dev/shm
# /dev/root       2.0G  1.1G  885M  55% /usr/sbin/docker-init
# tmpfs           6.4G  220K  6.4G   1% /var/colab
# /dev/sda1        46G   28G   18G  62% /etc/hosts
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
from google.colab import drive
drive.mount('/content/drive')
# Observar que al montar la carpeta se puede navegar en Google Drive desde el explorar de carpetas que está a la
# izquierda en Google Colab
# Out:
# Mounted at /content/drive

# %%
# Muestra las unidades montadas
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   28G   81G  26% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.8G     0  5.8G   0% /dev/shm
# /dev/root       2.0G  1.1G  885M  55% /usr/sbin/docker-init
# tmpfs           6.4G  224K  6.4G   1% /var/colab
# /dev/sda1        46G   28G   18G  62% /etc/hosts
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# drive           108G   32G   77G  29% /content/drive

# %%
# Aunque reiniciemos el entorno de ejecución la unidad continúa montada

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Crear un fichero en Drive desde Google Colab

# %%
with open('/content/drive/MyDrive/Master FP IA y BD/SNS/ACT1_1/nestorPruebaFichero_01.txt', 'w') as f:
  f.write('Hello Google Drive 01!')

# !cat '/content/drive/MyDrive/Master FP IA y BD/SNS/ACT1_1/nestorPruebaFichero_01.txt'
# Out:
# Hello Google Drive 01!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Desmonta las unidades montadas

# %%
drive.flush_and_unmount()

# %%
# Muestra las unidades montadas
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   28G   81G  26% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.8G     0  5.8G   0% /dev/shm
# /dev/root       2.0G  1.1G  885M  55% /usr/sbin/docker-init
# tmpfs           6.4G  320K  6.4G   1% /var/colab
# /dev/sda1        46G   28G   18G  62% /etc/hosts
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
# !ls -l
# Out:
# total 20
# -rw-r--r-- 1 root root 5878 Oct 21 10:27 'loremIpsum (1).txt'
# -rw-r--r-- 1 root root 5878 Oct 21 10:23  loremIpsum.txt
# drwxr-xr-x 1 root root 4096 Oct 19 16:36  sample_data

# %% [markdown]
# ### Crear un directorio en Google Drive

# %%
from google.colab import drive
drive.flush_and_unmount # Lo utilizo para poder hacer el ejemplo con autonomía de otras celdas

drive.mount('/content/drive', force_remount=True)

# !mkdir '/content/drive/MyDrive/Master FP IA y BD/SNS/ACT1_1/GoogleColab_test_2023_2024'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Ejer 03: Crear en drive un directorio llamado GoogleColab_test_Ejer_23_24 y dentro de ella un fichero con un contenido de Loren Ipsum. Consultar/verificar su creación en Google Drive y en el navegador de Google Colab

# %%
from google.colab import drive
drive.flush_and_unmount # Lo utilizo para poder hacer el ejemplo con autonomía de otras celdas

drive.mount('/content/drive', force_remount=True)

# !mkdir '/content/drive/MyDrive/Master FP IA y BD/SNS/ACT1_1/GoogleColab_test_Ejer_23_24'

with open('/content/drive/MyDrive/Master FP IA y BD/SNS/ACT1_1/GoogleColab_test_Ejer_23_24/lorenIpsum.txt', 'w') as f:
  f.write('Lorem ipsum dolor sit amet consectetur adipiscing elit elementum, aptent a ridiculus vivamus inceptos sagittis tempor nisi vehicula, nulla montes mollis sed dictumst eu mi. Aenean eget non nisl montes a magna, dapibus imperdiet velit vestibulum ligula, sem nunc in pulvinar aptent. Pellentesque congue aliquam nec libero id nibh est odio purus, ac velit tempus erat eget morbi vestibulum suscipit tincidunt, senectus nulla cubilia tristique pharetra facilisis sagittis quisque. Quam lobortis phasellus curae arcu etiam sodales rhoncus molestie malesuada conubia sociosqu nascetur duis, facilisis torquent sagittis platea tempus erat sociis turpis mattis porttitor iaculis.')

# !cat '/content/drive/MyDrive/Master FP IA y BD/SNS/ACT1_1/GoogleColab_test_Ejer_23_24/lorenIpsum.txt'
# Out:
# Mounted at /content/drive
# Lorem ipsum dolor sit amet consectetur adipiscing elit elementum, aptent a ridiculus vivamus inceptos sagittis tempor nisi vehicula, nulla montes mollis sed dictumst eu mi. Aenean eget non nisl montes a magna, dapibus imperdiet velit vestibulum ligula, sem nunc in pulvinar aptent. Pellentesque congue aliquam nec libero id nibh est odio purus, ac velit tempus erat eget morbi vestibulum suscipit tincidunt, senectus nulla cubilia tristique pharetra facilisis sagittis quisque. Quam lobortis phasellus curae arcu etiam sodales rhoncus molestie malesuada conubia sociosqu nascetur duis, facilisis torquent sagittis platea tempus erat sociis turpis mattis porttitor iaculis.

# %% [markdown]
# Navegador Google Colab
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Google Drive
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Uso de PyDrive

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
uploaded = drive.CreateFile({'title': 'Sample upload 2324.txt'})
uploaded.SetContentString('Sample upload file content')
# En este caso lo ccrea y sube en el direcotio raíz de Drive, en el caso de que deseemos utilizar un directorio en concreto se lo pasamos por parámetro
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1MktDuO-SUJ-NsymBrLOlLh5NFjZYAEnf

# %%
file = drive.CreateFile({'id': uploaded.get('id')})
print('Downloaded content "{}"'.format(file.GetContentString()))
# Out:
# Downloaded content "Sample upload file content"

# %%
# Para mostrar los directorios/ficheros y sus id's
# Fijarse que el nombre del fichero/directorio se identificaca con "Title"
file_list = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
for file1 in file_list:
    print('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: Sample upload 2324.txt, id: 1MktDuO-SUJ-NsymBrLOlLh5NFjZYAEnf
# title: Economía 2023, id: 1uCdqRaiM07o2rn2xOz-lUzFVdUGgd_kQFB4s5w6iv24
# title: Master FP IA y BD, id: 1iKrxrtl5NBX7judlqM_9cANwM7BeyQw4
# title: Notas, id: 1csH3Ao6piPyEhJaNwhJNaBAeWVeWoAi1tx-YdPfl8oQ
# title: Colab Notebooks, id: 15tdBpeEDx6l2zBDSzsM0OeAH9li3gAqH
# title: Hoja de cálculo sin título, id: 1rEtKiQpAVupCBrJo35CeD-dAoYj7-ixF_Dy08kcsGR8
# title: Firma de matrícula -m .docx.pdf, id: 1nTFCdGDsj39-w1F3fQbSkYYdeIVo7VcX
# title: TARJETA_SANITARIA_NBD.pdf, id: 1wCd3PP9Onl_QGsHJ95HT2EdQ3A5ILWT7
# title: IMG_20230511_091300.pdf, id: 1GNt9oaVbtvP7lo1KK_pvmnTjPex2oNkt
# title: Nomina Junio 2023.pdf, id: 1E0tACDbBWP6iQOh4S8Kj1Og55VgYDRsr
# title: Justificante de la operación realizada.pdf, id: 1ZyA0QzNwc29JLWY6czBqBHkovXd0PlQq
# title: IMG_20230511_091300.jpg, id: 1L2jzwBYYCoZ1krWI3ARehkh67WA7gdkG
# title: IMG_20230511_091442.jpg, id: 1rwA1tumS2Krb976ttdz8Fj3Gzk1A-BRt
# ...

# %% [markdown]
# ### Ejer 04: En la carpeta creada en el ejercicio anterior (GoogleColab_test_Ejer_23_24), crear un fichero cuyo nombre sean tu nombre y apellidos, en su contenido incluir un texto LorenIpsum distinto al utilizado en el punto anterior (de 50 palabras y añadir tu nombre al principio) y al terminar mostrar su contenido. Similar al ejemplo. Validar su existencia consultando Gdrive.ListFile  y el explorador de archivos de GoogleColab en este notebook

# %%
folderName = 'GoogleColab_test_Ejer_23_24'  # Please set the folder name.

folders = drive.ListFile(
    {'q': "title='" + folderName + "' and mimeType='application/vnd.google-apps.folder' and trashed=false"}).GetList()
for folder in folders:
    if folder['title'] == folderName:
        file2 = drive.CreateFile({'title': 'NestorBatistaDiaz.txt','parents': [{'id': folder['id']}]})
        file2.SetContentString('Néstor Batista Díaz\n\nLorem ipsum dolor sit amet consectetur adipiscing, elit ut rhoncus nullam egestas lacinia, cursus morbi quisque torquent mauris. Turpis sollicitudin tincidunt facilisis erat nam, orci in blandit aptent purus nostra, imperdiet tortor netus ridiculus. Arcu tristique congue ullamcorper platea sagittis, vitae fusce dapibus ultricies enim odio, habitasse et dis natoque.')
        file2.Upload()

file3 = drive.CreateFile({'id': file2.get('id')})
print('Contenido del fichero ', file3['title'], ':')
print(file3.GetContentString())
# Out:
# Contenido del fichero  NestorBatistaDiaz.txt :
# Néstor Batista Díaz
#
# Lorem ipsum dolor sit amet consectetur adipiscing, elit ut rhoncus nullam egestas lacinia, cursus morbi quisque torquent mauris. Turpis sollicitudin tincidunt facilisis erat nam, orci in blandit aptent purus nostra, imperdiet tortor netus ridiculus. Arcu tristique congue ullamcorper platea sagittis, vitae fusce dapibus ultricies enim odio, habitasse et dis natoque.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Ejer 05: Mostrar una lista de los ficheros que existen en el directorio GoogleColab_test_Ejer_23_24

# %%
for folder in folders:
    if folder['title'] == folderName:
      file_list2 = drive.ListFile({'q': "'"+folder['id']+"' in parents and trashed=false"}).GetList()
      for file2 in file_list2:
        print('title: %s, id: %s' % (file2['title'], file2['id']))
# Out:
# title: .ipynb_checkpoints, id: 1-LdeUbjhougOp88U-Tvn8nsFW0S8Rcx1
# title: NestorBatistaDiaz.txt, id: 1FmniA0XKlbbOwmv-sYkb05XifhsDcExp
# title: lorenIpsum.txt, id: 1-DxLUJ7w3kRNy3kLKMal7bxjMo0pTVaX

# %% [markdown]
# ## API de REST de Drive

# %% [markdown]
# ### Crear un archivo de Drive nuevo con datos de Python

# %%
from google.colab import auth
auth.authenticate_user()
from googleapiclient.discovery import build
drive_service = build('drive', 'v3')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
with open('/tmp/to_upload_23_24.txt', 'w') as f:
  f.write('Este año tenenmos nuevos retos.')

print('/tmp/to_upload_23_24.txt contains:')
# !cat /tmp/to_upload_23_24.txt
# Out:
# /tmp/to_upload_23_24.txt contains:
# Este año tenenmos nuevos retos.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from googleapiclient.http import MediaFileUpload


file_metadata = {
  'name': 'Sample file 23_24',
  'mimeType': 'text/plain'
}
media = MediaFileUpload('/tmp/to_upload_23_24.txt',
                        mimetype='text/plain',
                        resumable=True)
created = drive_service.files().create(body=file_metadata,
                                       media_body=media,
                                       fields='id').execute()
print('File ID: {}'.format(created.get('id')))
# Out:
# File ID: 1fL-4cqpeetytKWCcqIYpObaRkVmyCjRX

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Descargar datos de un archivo de Drive a un archivo lógico

# %%
file_id = created.get('id')

import io
from googleapiclient.http import MediaIoBaseDownload

request = drive_service.files().get_media(fileId=file_id)
downloaded = io.BytesIO()
downloader = MediaIoBaseDownload(downloaded, request)
done = False
while done is False:
  # _ is a placeholder for a progress object that we ignore.
  # (Our file is small, so we skip reporting progress.)
  _, done = downloader.next_chunk()

downloaded.seek(0)
print('Downloaded file contents are: {}'.format(downloaded.read()))
# Out:
# Downloaded file contents are: b'Este a\xc3\xb1o tenenmos nuevos retos.'

# %% [markdown]
# ### Ejer 06: Haciendo uso de la api (ejemplo anterior) descargar/mostrar el contenido del fichero que creaste con contenido LorenIpsum en la carpeta GoogleColab_test_Ejer y con el nombre tuyo.

# %%
file_id = file3.get('id')

import io
from googleapiclient.http import MediaIoBaseDownload

request = drive_service.files().get_media(fileId=file_id)
downloaded = io.BytesIO()
downloader = MediaIoBaseDownload(downloaded, request)
done = False
while done is False:
  # _ is a placeholder for a progress object that we ignore.
  # (Our file is small, so we skip reporting progress.)
  _, done = downloader.next_chunk()

downloaded.seek(0)
print('Downloaded file contents are: {}'.format(downloaded.read()))
# Out:
# Downloaded file contents are: b'N\xc3\xa9stor Batista D\xc3\xadaz\n\nLorem ipsum dolor sit amet consectetur adipiscing, elit ut rhoncus nullam egestas lacinia, cursus morbi quisque torquent mauris. Turpis sollicitudin tincidunt facilisis erat nam, orci in blandit aptent purus nostra, imperdiet tortor netus ridiculus. Arcu tristique congue ullamcorper platea sagittis, vitae fusce dapibus ultricies enim odio, habitasse et dis natoque.'

# %% [markdown]
# ## Hojas de cálculo de Google

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %% [markdown]
# ### Crear una hoja nueva con datos de Python

# %%
# Crea la hoja de cálcula en el directorio raíz de Google Drive
sh = gc.create('My cool spreadsheet_23_24')

# %%
worksheet = gc.open('My cool spreadsheet_23_24').sheet1

cell_list = worksheet.range('A1:C2')

import random
for cell in cell_list:
  cell.value = random.randint(1, 10)

worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1qHu-A9hg28uaAvd2_LzJ2jkbtEf1iUroHSpZjvBhitI',
#  'updatedRange': "'Hoja 1'!A1:C2",
#  'updatedRows': 2,
#  'updatedColumns': 3,
#  'updatedCells': 6}

# %% [markdown]
# ### Descargar datos de una hoja de cálculo en Python como un DataFrame de Pandas

# %%
worksheet = gc.open('My cool spreadsheet_23_24').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)

import pandas as pd
df_Example01 = pd.DataFrame.from_records(rows)
# Out:
# [['2', '9', '5'], ['9', '1', '3']]

# %% [markdown]
# ### Ejer 07: Subir a un repositorio de GitHub una hoja de cálculo en formato csv y realizar la importanción a un dataframe, utilizando como separador de campos un "punto y coma" ;

# %%
import pandas as pd
# Importación de los datos

repositorio = 'https://raw.githubusercontent.com/Nestorbd/Analisis-de-sentimientos-con-Python/master/code/data.csv'

sentences = pd.read_csv(repositorio)

sentences
# Out:
#                                                Sentence Sentiment
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish-Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5888  In a surprising turn of events, XYZ Pharma fac...  negative
# 5889  GreenTech Solutions announces plans for a $200...  positive
# 5890  Despite economic challenges, XYZ Construction ...  positive
# 5891  After extensive research and development, XYZ ...  positive
# 5892  Market analysts speculate a potential merger b...   neutral
#
# [5893 rows x 2 columns]
